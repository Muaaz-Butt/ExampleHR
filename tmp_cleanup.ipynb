# %%
from pathlib import Path
import shutil

root = Path(r'C:\Users\Muaaz Butt\OneDrive\Documents\Wizdaa_Home_Assignment')
paths = [root / 'body.json', root / 'scripts' / 'check-endpoints.js', root / 'scripts' / 'check-request-flow.js']
for path in paths:
    if path.exists() and path.is_file():
        path.unlink()

scripts_dir = root / 'scripts'
if scripts_dir.exists():
    shutil.rmtree(scripts_dir, ignore_errors=True)

cleanup_file = root / 'tmp_cleanup.ipynb'
if cleanup_file.exists():
    cleanup_file.unlink()

print('cleanup-complete')
# Out:
# cleanup-complete

# %%
from pathlib import Path
cleanup_file = Path(r'C:\Users\Muaaz Butt\OneDrive\Documents\Wizdaa_Home_Assignment\tmp_cleanup.ipynb')
if cleanup_file.exists():
    cleanup_file.unlink()
    print('notebook-deleted')
else:
    print('notebook-missing')

# %%
from pathlib import Path

scripts_dir = Path('C:/Users/Muaaz Butt/OneDrive/Documents/Wizdaa_Home_Assignment/scripts')
if scripts_dir.exists():
    print('scripts exists before', list(scripts_dir.iterdir()))
    try:
        scripts_dir.rmdir()
        print('scripts removed')
    except Exception as exc:
        print('remove failed', type(exc).__name__, exc)
else:
    print('scripts does not exist')
